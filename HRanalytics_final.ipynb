# %%
import pandas as pd
from pathlib import Path
data_dir = Path("datasets")

# HR promotions: predict is_promoted
filepath = data_dir / 'HR analytics' / 'promotions.csv'
promotions = pd.read_csv(filepath)
promotions.shape

# 4.a 54808 examples
# 4.b 13 features, 1 label
# Out:
# (54808, 14)

# %%
promotions.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
promotions = promotions.rename(columns=str.lower)

# %%
promotions.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'kpis_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
promotions_tmp = pd.get_dummies(promotions)
promotions_tmp.corr()
# Out:
#                               employee_id  no_of_trainings       age  \
# employee_id                      1.000000        -0.005121  0.000437
# no_of_trainings                 -0.005121         1.000000 -0.081278
# age                              0.000437        -0.081278  1.000000
# previous_year_rating             0.004533        -0.063126  0.006008
# length_of_service                0.001274        -0.057275  0.657111
# kpis_met >80%                   -0.002501        -0.045576 -0.025592
# awards_won?                      0.008420        -0.007628 -0.008169
# avg_training_score              -0.000586         0.042517 -0.048380
# is_promoted                      0.001206        -0.024896 -0.017166
# department_Analytics            -0.001291         0.045791 -0.101895
# department_Finance               0.007139         0.018442 -0.078936
# department_HR                    0.007994        -0.070258 -0.011725
# department_Legal                -0.006410        -0.037305 -0.017628
# department_Operations           -0.001602        -0.077320  0.084703
# department_Procurement           0.005393         0.044313  0.055369
# department_R&D                  -0.005754         0.033410 -0.034883
# department_Sales & Marketing    -0.002645         0.026698  0.004931
# department_Technology           -0.003148         0.004984  0.003196
# region_region_1                 -0.004768        -0.014940 -0.042511
# region_region_10                -0.005571        -0.013285 -0.012361
# region_region_11                -0.003557        -0.016969 -0.034697
# region_region_12                -0.004312        -0.011183 -0.051456
# region_region_13                 0.004382        -0.027509  0.027639
# region_region_14                -0.006351        -0.024379 -0.007031
# region_region_15                 0.005751        -0.008755  0.021246
# region_region_16                 0.000520        -0.017947 -0.010821
# region_region_17                 0.004752        -0.024631  0.011569
# region_region_18                 0.004893        -0.007360 -0.012314
# region_region_19                -0.003345        -0.012941  0.021759
# region_region_2                  0.000808         0.044026  0.282070
# region_region_20                 0.001004        -0.011648 -0.040506
# region_region_21                -0.001769        -0.004855 -0.016798
# region_region_22                 0.002801         0.091366 -0.118138
# region_region_23                 0.006762        -0.003368 -0.005272
# region_region_24                 0.003439        -0.003916 -0.045248
# region_region_25                 0.003393        -0.005484 -0.046733
# region_region_26                -0.003920        -0.020454 -0.037541
# region_region_27                -0.003667         0.002492 -0.046361
# region_region_28                 0.010397         0.002645 -0.044585
# region_region_29                 0.000921        -0.017615 -0.055781
# region_region_3                 -0.003214        -0.016463 -0.013297
# region_region_30                -0.001016        -0.017124 -0.036795
# region_region_31                -0.000763         0.002990 -0.043864
# region_region_32                 0.002975        -0.005313 -0.062702
# region_region_33                -0.003406        -0.015881  0.010796
# region_region_34                -0.006627        -0.006121 -0.038732
# region_region_4                  0.002578        -0.020172  0.031325
# region_region_5                  0.001569        -0.012706 -0.031608
# region_region_6                 -0.006717        -0.016540 -0.061456
# region_region_7                 -0.007902         0.005030  0.034153
# region_region_8                  0.003565        -0.032443 -0.043523
# region_region_9                 -0.001755         0.000939 -0.059563
# education_Bachelor's            -0.002584         0.041708 -0.252190
# education_Below Secondary       -0.003680         0.004562 -0.174815
# education_Master's & above       0.002619        -0.034053  0.363260
# gender_f                         0.001542        -0.084501  0.016293
# gender_m                        -0.001542         0.084501 -0.016293
# recruitment_channel_other       -0.005920         0.012225  0.017304
# recruitment_channel_referred     0.000269        -0.013615 -0.042124
# recruitment_channel_sourcing     0.005875        -0.008358 -0.005225
#
#                               previous_year_rating  length_of_service  \
# employee_id                               0.004533           0.001274
# no_of_trainings                          -0.063126          -0.057275
# age                                       0.006008           0.657111
# previous_year_rating                      1.000000           0.000253
# length_of_service                         0.000253           1.000000
# kpis_met >80%                             0.351578          -0.077693
# awards_won?                               0.027738          -0.039927
# avg_training_score                        0.075139          -0.038122
# is_promoted                               0.159320          -0.010670
# department_Analytics                      0.059118          -0.071945
# department_Finance                        0.030330          -0.054025
# department_HR                             0.025813          -0.009162
# department_Legal                          0.007979          -0.041259
# department_Operations                     0.124803           0.065956
# department_Procurement                   -0.009425           0.042237
# department_R&D                            0.025176          -0.041881
# department_Sales & Marketing             -0.137843           0.007305
# department_Technology                    -0.052347           0.004474
# region_region_1                           0.008049          -0.026912
# region_region_10                         -0.006061          -0.004743
# region_region_11                          0.003309          -0.021670
# region_region_12                         -0.000958          -0.038009
# region_region_13                          0.003145           0.017259
# region_region_14                         -0.000186           0.001938
# region_region_15                          0.002955           0.019920
# region_region_16                         -0.011441          -0.006816
# region_region_17                          0.012458           0.011373
# region_region_18                         -0.013605          -0.009686
# region_region_19                          0.002905           0.017469
# region_region_2                           0.000823           0.183163
# region_region_20                          0.003203          -0.026370
# region_region_21                         -0.008042          -0.013722
# region_region_22                          0.016352          -0.084500
# region_region_23                          0.004554           0.000385
# region_region_24                         -0.044836          -0.027441
# region_region_25                          0.014688          -0.029543
# region_region_26                         -0.006044          -0.030768
# region_region_27                         -0.010808          -0.035104
# region_region_28                          0.017032          -0.030542
# region_region_29                         -0.025657          -0.035017
# region_region_3                           0.010810          -0.008991
# region_region_30                         -0.008755          -0.023571
# region_region_31                         -0.014189          -0.033675
# region_region_32                         -0.006081          -0.045151
# region_region_33                         -0.017449           0.016661
# region_region_34                         -0.020509          -0.026017
# region_region_4                           0.033923           0.028181
# region_region_5                          -0.026234          -0.018111
# region_region_6                          -0.012994          -0.041024
# region_region_7                           0.019127           0.026352
# region_region_8                           0.007900          -0.032593
# region_region_9                          -0.035021          -0.040693
# education_Bachelor's                     -0.005466          -0.173673
# education_Below Secondary                 0.012444          -0.119119
# education_Master's & above                0.016968           0.249536
# gender_f                                  0.024232           0.019675
# gender_m                                 -0.024232          -0.019675
# recruitment_channel_other                -0.016076           0.007202
# recruitment_channel_referred              0.070667          -0.030292
# recruitment_channel_sourcing             -0.003986           0.001513
#
#                               kpis_met >80%  awards_won?  avg_training_score  \
# employee_id                       -0.002501     0.008420           -0.000586
# no_of_trainings                   -0.045576    -0.007628            0.042517
# age                               -0.025592    -0.008169           -0.048380
# previous_year_rating               0.351578     0.027738            0.075139
# kpis_met >80%                    0.221582              0.035938
# awards_won?                      0.195871              0.002445
# avg_training_score               0.181147              0.521961
# is_promoted                      1.000000              0.012369
# department_Analytics             0.012369              1.000000
# department_Finance              -0.003109             -0.072458
# department_HR                   -0.022262             -0.070673
# department_Legal                -0.017011             -0.045729
# department_Operations            0.009113             -0.168098
# department_Procurement           0.015548             -0.127296
# department_R&D                  -0.007859             -0.044823
# department_Sales & Marketing    -0.031348             -0.219084
# department_Technology            0.031085             -0.127296
# region_region_1                  0.003767              0.009628
# region_region_10                -0.002534             -0.021198
# region_region_11                -0.016231             -0.000165
# region_region_12                -0.006590             -0.007645
# region_region_13                 0.001363             -0.035996
# region_region_14                -0.004523             -0.016516
# region_region_15                -0.005087             -0.011208
# region_region_16                -0.009229             -0.032033
# region_region_17                 0.022513             -0.026577
# region_region_18                -0.004509             -0.007826
# region_region_19                -0.011187             -0.009493
# region_region_2                 -0.009742             -0.066848
# region_region_20                -0.012376              0.003481
# region_region_21                -0.012884              0.004892
# region_region_22                 0.037893              0.092900
# region_region_23                 0.016664             -0.008376
# region_region_24                -0.017234             -0.008727
# region_region_25                 0.017911              0.038009
# region_region_26                -0.016268              0.007824
# region_region_27                -0.003929             -0.010046
# region_region_28                 0.017812              0.048266
# region_region_29                -0.020406              0.071365
# region_region_3                  0.006215             -0.004491
# region_region_30                 0.001828             -0.000653
# region_region_31                -0.019411              0.024329
# region_region_32                -0.020330              0.047087
# region_region_33                -0.012076             -0.020465
# region_region_34                -0.015147              0.015609
# region_region_4                  0.038031             -0.011087
# region_region_5                 -0.016838             -0.013509
# region_region_6                 -0.015693             -0.009029
# region_region_7                  0.023841             -0.018174
# region_region_8                 -0.001676             -0.009028
# region_region_9                 -0.020817              0.029595
# education_Bachelor's            -0.015988              0.051893
# education_Below Secondary       -0.000849             -0.040164
# education_Master's & above       0.029343             -0.058052
# gender_f                         0.011109             -0.145173
# gender_m                        -0.011109              0.145173
# recruitment_channel_other       -0.004879             -0.000006
# recruitment_channel_referred     0.018641             -0.012271
# recruitment_channel_sourcing    -0.000483              0.003554
#
#                               department_Finance  department_HR  \
# employee_id                             0.007139       0.007994
# no_of_trainings                         0.018442      -0.070258
# age                                    -0.078936      -0.011725
# previous_year_rating                    0.030330       0.025813
# length_of_service                      -0.054025      -0.009162
# kpis_met >80%                           0.028987      -0.008013
# awards_won?                             0.006487      -0.006513
# avg_training_score                     -0.052132      -0.214788
# is_promoted                            -0.003109      -0.022262
# department_Analytics                   -0.072458      -0.070673
# department_Finance                      1.000000      -0.047320
# department_HR                          -0.047320       1.000000
# department_Legal                       -0.030618      -0.029864
# department_Operations                  -0.112552      -0.109779
# department_Procurement                 -0.085233      -0.083132
# department_R&D                         -0.030012      -0.029272
# department_Sales & Marketing           -0.146691      -0.143076
# department_Technology                  -0.085233      -0.083132
# region_region_1                        -0.017572      -0.016863
# region_region_10                       -0.013647      -0.011169
# region_region_11                       -0.002183      -0.009879
# region_region_12                       -0.011999      -0.012203
# region_region_13                       -0.014389      -0.014015
# region_region_14                       -0.010876      -0.014930
# region_region_15                       -0.021245      -0.022923
# region_region_16                       -0.021963      -0.015221
# region_region_17                       -0.026013      -0.011970
# region_region_18                       -0.005240      -0.005111
# region_region_19                       -0.014172      -0.023093
# region_region_2                         0.052997       0.078583
# region_region_20                       -0.010073       0.019774
# region_region_21                       -0.013105      -0.013525
# region_region_22                        0.010142       0.012816
# region_region_23                       -0.015212      -0.002968
# region_region_24                       -0.017679      -0.008726
# region_region_25                       -0.014243      -0.001562
# region_region_26                        0.020718      -0.003890
# region_region_27                       -0.004949      -0.010471
# region_region_28                        0.019285      -0.006465
# region_region_29                       -0.001948      -0.008558
# region_region_3                        -0.013170       0.001947
# region_region_30                        0.022825      -0.017133
# region_region_31                       -0.005899      -0.005473
# region_region_32                        0.013528       0.015909
# region_region_33                       -0.012983      -0.012545
# region_region_34                       -0.008961      -0.010841
# region_region_4                         0.010613      -0.014917
# region_region_5                        -0.018085      -0.016495
# region_region_6                         0.009405      -0.014696
# region_region_7                        -0.001251       0.006993
# region_region_8                        -0.009038      -0.013816
# region_region_9                        -0.010392      -0.018879
# education_Bachelor's                    0.036602      -0.017513
# education_Below Secondary               0.049638       0.068306
# education_Master's & above             -0.037381       0.014878
# gender_f                               -0.014013       0.055646
# gender_m                                0.014013      -0.055646
# recruitment_channel_other               0.009481       0.006579
# recruitment_channel_referred           -0.029091       0.032730
# recruitment_channel_sourcing           -0.001126      -0.016077
#
#                               department_Legal  department_Operations  \
# employee_id                          -0.006410              -0.001602
# no_of_trainings                      -0.037305              -0.077320
# age                                  -0.017628               0.084703
# previous_year_rating                  0.007979               0.124803
# length_of_service                    -0.041259               0.065956
# kpis_met >80%                        -0.005239               0.084272
# awards_won?                           0.000822              -0.000285
# avg_training_score                   -0.036579              -0.120764
# is_promoted                          -0.017011               0.009113
# department_Analytics                 -0.045729              -0.168098
# department_Finance                   -0.030618              -0.112552
# department_HR                        -0.029864              -0.109779
# department_Legal                      1.000000              -0.071032
# department_Operations                -0.071032               1.000000
# department_Procurement               -0.053791              -0.197734
# department_R&D                       -0.018941              -0.069626
# department_Sales & Marketing         -0.092577              -0.340312
# department_Technology                -0.053791              -0.197734
# region_region_1                      -0.013472              -0.028028
# region_region_10                     -0.015205              -0.019650
# region_region_11                     -0.002560               0.002569
# region_region_12                      0.003548               0.023432
# region_region_13                     -0.011355              -0.001736
# region_region_14                     -0.017206               0.007672
# region_region_15                     -0.021380               0.078347
# region_region_16                     -0.013912              -0.002604
# region_region_17                     -0.013520              -0.027406
# region_region_18                     -0.003307              -0.006474
# region_region_19                     -0.016628               0.065436
# region_region_2                       0.042603              -0.045558
# region_region_20                      0.004208               0.000003
# region_region_21                     -0.010532               0.015608
# region_region_22                      0.046215               0.030100
# region_region_23                     -0.015957              -0.009726
# region_region_24                     -0.002276              -0.008543
# region_region_25                     -0.010505              -0.035101
# region_region_26                     -0.001913              -0.016291
# region_region_27                      0.016048               0.009857
# region_region_28                     -0.020074              -0.045821
# region_region_29                     -0.008866               0.007151
# region_region_3                      -0.007701               0.004185
# region_region_30                     -0.014082              -0.005392
# region_region_31                     -0.002669               0.003747
# region_region_32                     -0.008134               0.030212
# region_region_33                     -0.009763              -0.021067
# region_region_34                      0.004530               0.004046
# region_region_4                      -0.016411               0.029947
# region_region_5                       0.003965              -0.031684
# region_region_6                      -0.007296               0.006921
# region_region_7                       0.003861              -0.018839
# region_region_8                      -0.012826               0.042840
# region_region_9                      -0.007613              -0.027348
# education_Bachelor's                  0.033796               0.018056
# education_Below Secondary             0.055318               0.003490
# education_Master's & above           -0.038150               0.007564
# gender_f                             -0.046886               0.127993
# gender_m                              0.046886              -0.127993
# recruitment_channel_other             0.003455              -0.002252
# recruitment_channel_referred         -0.007165               0.000488
# recruitment_channel_sourcing         -0.001403               0.002123
#
#                               department_Procurement  ...  region_region_34  \
# employee_id                                 0.005393  ...         -0.006627
# no_of_trainings                             0.044313  ...         -0.006121
# age                                         0.055369  ...         -0.038732
# previous_year_rating                       -0.009425  ...         -0.020509
# length_of_service                           0.042237  ...         -0.026017
# kpis_met >80%                               0.020728  ...         -0.013528
# awards_won?                                 0.002018  ...         -0.001276
# avg_training_score                          0.194926  ...         -0.003410
# is_promoted                                 0.015548  ...         -0.015147
# department_Analytics                       -0.127296  ...          0.015609
# department_Finance                         -0.085233  ...         -0.008961
# department_HR                              -0.083132  ...         -0.010841
# department_Legal                           -0.053791  ...          0.004530
# department_Operations                      -0.197734  ...          0.004046
# department_Procurement                      1.000000  ...         -0.000766
# department_R&D                             -0.052726  ...         -0.009972
# department_Sales & Marketing               -0.257708  ...          0.008302
# department_Technology                      -0.149738  ...         -0.014916
# region_region_1                            -0.031751  ...         -0.007764
# region_region_10                            0.033908  ...         -0.008005
# region_region_11                            0.000970  ...         -0.011475
# region_region_12                           -0.001778  ...         -0.007022
# region_region_13                            0.020259  ...         -0.016490
# region_region_14                            0.004578  ...         -0.009059
# region_region_15                           -0.001403  ...         -0.017007
# region_region_16                            0.004102  ...         -0.012129
# region_region_17                            0.111169  ...         -0.008885
# region_region_18                           -0.009206  ...         -0.001741
# region_region_19                           -0.012475  ...         -0.009317
# region_region_2                             0.056907  ...         -0.039457
# region_region_20                           -0.000746  ...         -0.009186
# region_region_21                           -0.002845  ...         -0.006362
# region_region_22                           -0.040969  ...         -0.026677
# region_region_23                            0.003732  ...         -0.010833
# region_region_24                            0.007829  ...         -0.007079
# region_region_25                           -0.037830  ...         -0.009014
# region_region_26                           -0.009906  ...         -0.015178
# region_region_27                           -0.007297  ...         -0.012930
# region_region_28                           -0.043402  ...         -0.011488
# region_region_29                           -0.022122  ...         -0.009947
# region_region_3                            -0.026052  ...         -0.005833
# region_region_30                            0.002707  ...         -0.008061
# region_region_31                           -0.016452  ...         -0.014001
# region_region_32                           -0.045841  ...         -0.009694
# region_region_33                           -0.007008  ...         -0.005140
# region_region_34                           -0.000766  ...          1.000000
# region_region_4                            -0.009621  ...         -0.013106
# region_region_5                             0.015811  ...         -0.008713
# no_of_trainings                     -0.016540         0.005030
# age                                 -0.061456         0.034153
# previous_year_rating                -0.012994         0.019127
# length_of_service                   -0.041024         0.026352
# kpis_met >80%                       -0.010575         0.005167
# awards_won?                         -0.002163        -0.001804
# avg_training_score                  -0.019396         0.012904
# is_promoted                         -0.015693         0.023841
# department_Analytics                -0.009029        -0.018174
# department_Finance                   0.009405        -0.001251
# department_HR                       -0.014696         0.006993
# department_Legal                    -0.007296         0.003861
# department_Operations                0.006921        -0.018839
# department_Procurement              -0.015979         0.008073
# department_R&D                      -0.012939         0.002751
# department_Sales & Marketing         0.019862        -0.006554
# department_Technology               -0.000420         0.033476
# region_region_1                     -0.011979        -0.033029
# region_region_10                    -0.012351        -0.034054
# region_region_11                    -0.017704        -0.048813
# region_region_12                    -0.010834        -0.029873
# region_region_13                    -0.025442        -0.070148
# region_region_14                    -0.013976        -0.038535
# region_region_15                    -0.026239        -0.072347
# region_region_16                    -0.018713        -0.051595
# region_region_17                    -0.013708        -0.037795
# region_region_18                    -0.002686        -0.007406
# region_region_19                    -0.014374        -0.039632
# region_region_2                     -0.060876        -0.167849
# region_region_20                    -0.014172        -0.039076
# region_region_21                    -0.009815        -0.027062
# region_region_22                    -0.041158        -0.113483
# region_region_23                    -0.016713        -0.046082
# region_region_24                    -0.010922        -0.030113
# region_region_25                    -0.013907        -0.038345
# region_region_26                    -0.023417        -0.064565
# region_region_27                    -0.019949        -0.055005
# region_region_28                    -0.017725        -0.048870
# region_region_29                    -0.015346        -0.042313
# region_region_3                     -0.009000        -0.024815
# region_region_30                    -0.012438        -0.034293
# region_region_31                    -0.021601        -0.059559
# region_region_32                    -0.014956        -0.041238
# region_region_33                    -0.007930        -0.021865
# region_region_34                    -0.008264        -0.022785
# region_region_4                     -0.020221        -0.055752
# region_region_5                     -0.013443        -0.037066
# region_region_6                      1.000000        -0.035154
# region_region_7                     -0.035154         1.000000
# region_region_8                     -0.012418        -0.034240
# region_region_9                     -0.009923        -0.027359
# education_Bachelor's                 0.066549        -0.051802
# education_Below Secondary           -0.008345         0.017564
# education_Master's & above          -0.062090         0.049126
# gender_f                             0.028147         0.019631
# gender_m                            -0.028147        -0.019631
# recruitment_channel_other           -0.003062         0.000867
# recruitment_channel_referred        -0.013035        -0.024263
# recruitment_channel_sourcing         0.006847         0.006142
#
#                               region_region_8  region_region_9  \
# employee_id                          0.003565        -0.001755
# no_of_trainings                     -0.032443         0.000939
# age                                 -0.043523        -0.059563
# previous_year_rating                 0.007900        -0.035021
# length_of_service                   -0.032593        -0.040693
# kpis_met >80%                        0.013520        -0.030154
# awards_won?                         -0.000198        -0.001018
# avg_training_score                   0.002419        -0.015341
# is_promoted                         -0.001676        -0.020817
# department_Analytics                -0.009028         0.029595
# department_Finance                  -0.009038        -0.010392
# department_HR                       -0.013816        -0.018879
# department_Legal                    -0.012826        -0.007613
# department_Operations                0.042840        -0.027348
# department_Procurement               0.014316        -0.024680
# department_R&D                       0.006353        -0.010410
# region_region_29                               -0.022631 -0.031052  0.031052
# region_region_3                                 0.012306 -0.026188  0.026188
# region_region_30                               -0.038758 -0.003130  0.003130
# region_region_31                               -0.024858 -0.015330  0.015330
# region_region_32                               -0.066229 -0.012033  0.012033
# region_region_33                               -0.003081 -0.020020  0.020020
# region_region_34                               -0.022249 -0.037225  0.037225
# region_region_4                                 0.081555 -0.003645  0.003645
# region_region_5                                -0.013824  0.001367 -0.001367
# region_region_6                                -0.062090  0.028147 -0.028147
# region_region_7                                 0.049126  0.019631 -0.019631
# region_region_8                                -0.000138  0.006999 -0.006999
# region_region_9                                -0.001115 -0.043474  0.043474
# education_Bachelor's                           -0.869773 -0.005042  0.005042
# education_Below Secondary                      -0.074688  0.016392 -0.016392
# education_Master's & above                      1.000000  0.030122 -0.030122
# gender_f                                        0.030122  1.000000 -1.000000
# gender_m                                       -0.030122 -1.000000  1.000000
# recruitment_channel_other                       0.008341  0.007520 -0.007520
# recruitment_channel_referred                   -0.028403 -0.007231  0.007231
# recruitment_channel_sourcing                   -0.000177 -0.005472  0.005472
#
#                               recruitment_channel_other  \
# employee_id                                   -0.005920
# no_of_trainings                                0.012225
# age                                            0.017304
# previous_year_rating                          -0.016076
# length_of_service                              0.007202
# kpis_met >80%                                 -0.006551
# awards_won?                                    0.005006
# avg_training_score                            -0.001999
# is_promoted                                   -0.004879
# department_Analytics                          -0.000006
# department_Finance                             0.009481
# department_HR                                  0.006579
# department_Legal                               0.003455
# department_Operations                         -0.002252
# department_Procurement                         0.004017
# department_R&D                                 0.000014
# department_Sales & Marketing                  -0.005147
# department_Technology                         -0.005583
# region_region_1                                0.004600
# region_region_10                              -0.001687
# region_region_11                               0.006602
# region_region_12                               0.004344
# region_region_13                               0.001888
# region_region_14                               0.008614
# region_region_15                               0.000524
# region_region_16                               0.006872
# region_region_17                               0.004548
# region_region_18                               0.004292
# region_region_19                               0.010989
# region_region_2                               -0.024926
# region_region_20                               0.007970
# region_region_21                               0.010082
# region_region_22                              -0.025422
# region_region_23                               0.011480
# region_region_24                               0.001841
# region_region_25                               0.003342
# region_region_26                               0.007860
# region_region_27                              -0.000767
# region_region_28                               0.005955
# region_region_29                               0.001604
# region_region_3                                0.006396
# region_region_30                              -0.001000
# region_region_31                               0.000219
# region_region_32                               0.003963
# region_region_33                               0.011333
# region_region_34                               0.007462
# region_region_4                                0.009941
# region_region_5                                0.007658
# region_region_6                               -0.003062
# region_region_7                                0.000867
# region_region_8                                0.007145
# region_region_9                               -0.000973
# education_Bachelor's                          -0.009265
# education_Below Secondary                     -0.008906
# education_Master's & above                     0.008341
# gender_f                                       0.007520
# gender_m                                      -0.007520
# recruitment_channel_other                      1.000000
# recruitment_channel_referred                  -0.163077
# recruitment_channel_sourcing                  -0.958470
#
#                               recruitment_channel_referred  \
# employee_id                                       0.000269
# no_of_trainings                                  -0.013615
# age                                              -0.042124
# previous_year_rating                              0.070667
# length_of_service                                -0.030292
# kpis_met >80%                                     0.047621
# awards_won?                                       0.003004
# avg_training_score                                0.030496
# is_promoted                                       0.018641
# department_Analytics                             -0.012271
# department_Finance                               -0.029091
# department_HR                                     0.032730
# department_Legal                                 -0.007165
# department_Operations                             0.000488
# department_Procurement                           -0.026465
# department_R&D                                   -0.001734
# department_Sales & Marketing                     -0.025440
# department_Technology                             0.073352
# region_region_1                                  -0.015476
# region_region_10                                 -0.015956
# region_region_11                                 -0.022872
# region_region_12                                 -0.013997
# region_region_13                                 -0.019762
# region_region_14                                 -0.018056
# region_region_15                                  0.011293
# region_region_16                                 -0.017839
# region_region_17                                 -0.013438
# region_region_18                                 -0.003470
# region_region_19                                 -0.018570
# region_region_2                                   0.092601
# region_region_20                                 -0.018309
# region_region_21                                 -0.012680
# region_region_22                                  0.099672
# region_region_23                                 -0.019828
# region_region_24                                 -0.014110
# region_region_25                                 -0.016914
# region_region_26                                 -0.020616
# region_region_27                                 -0.022790
# region_region_28                                 -0.020397
# region_region_29                                 -0.017911
# region_region_3                                  -0.011627
# region_region_30                                 -0.016068
# region_region_31                                 -0.027214
# region_region_32                                 -0.017359
# region_region_33                                 -0.010245
# region_region_34                                 -0.010676
# region_region_4                                  -0.023914
# region_region_5                                  -0.015191
# region_region_6                                  -0.013035
# region_region_7                                  -0.024263
# region_region_8                                  -0.016043
# region_region_9                                  -0.012819
# education_Bachelor's                              0.032290
# education_Below Secondary                         0.023601
# education_Master's & above                       -0.028403
# gender_f                                         -0.007231
# gender_m                                          0.007231
# recruitment_channel_other                        -0.163077
# recruitment_channel_referred                      1.000000
# recruitment_channel_sourcing                     -0.125070
#
#                               recruitment_channel_sourcing
# employee_id                                       0.005875
# no_of_trainings                                  -0.008358
# age                                              -0.005225
# previous_year_rating                             -0.003986
# length_of_service                                 0.001513
# kpis_met >80%                                    -0.007178
# awards_won?                                      -0.005902
# avg_training_score                               -0.006805
# is_promoted                                      -0.000483
# department_Analytics                              0.003554
# department_Finance                               -0.001126
# department_HR                                    -0.016077
# department_Legal                                 -0.001403
# department_Operations                             0.002123
# department_Procurement                            0.003610
# department_R&D                                    0.000487
# department_Sales & Marketing                      0.012529
# department_Technology                            -0.015589
# region_region_1                                  -0.000152
# region_region_10                                  0.006309
# region_region_11                                 -0.000027
# region_region_12                                 -0.000322
# region_region_13                                  0.003814
# region_region_14                                 -0.003443
# region_region_15                                 -0.003792
# region_region_16                                 -0.001754
# region_region_17                                 -0.000689
# region_region_18                                 -0.003313
# region_region_19                                 -0.005683
# region_region_2                                  -0.001701
# region_region_20                                 -0.002723
# region_region_21                                 -0.006473
# region_region_22                                 -0.003247
# region_region_23                                 -0.005813
# region_region_24                                  0.002227
# region_region_25                                  0.001528
# region_region_26                                 -0.001945
# region_region_27                                  0.007359
# region_region_28                                 -0.000093
# region_region_29                                  0.003564
# region_region_3                                  -0.003071
# region_region_30                                  0.005651
# region_region_31                                  0.007646
# region_region_32                                  0.001033
# region_region_33                                 -0.008435
# region_region_34                                 -0.004417
# region_region_4                                  -0.003084
# region_region_5                                  -0.003310
# region_region_6                                   0.006847
# region_region_7                                   0.006142
# region_region_8                                  -0.002548
# region_region_9                                   0.004684
# education_Bachelor's                             -0.000017
# education_Below Secondary                         0.002134
# education_Master's & above                       -0.000177
# gender_f                                         -0.005472
# gender_m                                          0.005472
# recruitment_channel_other                        -0.958470
# recruitment_channel_referred                     -0.125070
# recruitment_channel_sourcing                      1.000000
#
# [60 rows x 60 columns]

# %%
promotions = promotions.drop(['employee_id','region','department','gender','recruitment_channel','education'], axis=1)

# 5.a we reomved the above features

# %%
promotions.head(20)
# Out:
#     no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                 1   35                   5.0                  8
# 1                 1   30                   5.0                  4
# 2                 1   34                   3.0                  7
# 3                 2   39                   1.0                 10
# 4                 1   45                   3.0                  2
# 5                 2   31                   3.0                  7
# 6                 1   31                   3.0                  5
# 7                 1   33                   3.0                  6
# 8                 1   28                   4.0                  5
# 9                 1   32                   5.0                  5
# 10                1   30                   NaN                  1
# 11                1   35                   5.0                  3
# 12                1   49                   5.0                  5
# 13                2   39                   3.0                 16
# 14                1   37                   3.0                  7
# 15                1   37                   1.0                 10
# 16                1   38                   3.0                  5
# 17                1   34                   1.0                  4
# 18                1   34                   5.0                  8
# 19                1   37                   3.0                  9
#
#     kpis_met >80%  awards_won?  avg_training_score  is_promoted
# 0               1            0                  49            0
# 1               0            0                  60            0
# 2               0            0                  50            0
# 3               0            0                  50            0
# 4               0            0                  73            0
# 5               0            0                  85            0
# 6               0            0                  59            0
# 7               0            0                  63            0
# 8               0            0                  83            0
# 9               1            0                  54            0
# 10              0            0                  77            0
# 11              1            0                  50            1
# 12              1            0                  49            0
# 13              0            0                  80            0
# 14              0            0                  84            0
# 15              0            0                  60            0
# 16              1            0                  77            0
# 17              0            0                  51            0
# 18              1            0                  46            0
# 19              0            0                  59            0

# %%
promotions.isna().mean()
# Out:
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    0.075244
# length_of_service       0.000000
# kpis_met >80%           0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64

# %%
promotions = pd.get_dummies(promotions)
promotions.head(10)
# Out:
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
# 5                2   31                   3.0                  7
# 6                1   31                   3.0                  5
# 7                1   33                   3.0                  6
# 8                1   28                   4.0                  5
# 9                1   32                   5.0                  5
#
#    kpis_met >80%  awards_won?  avg_training_score  is_promoted
# 0              1            0                  49            0
# 1              0            0                  60            0
# 2              0            0                  50            0
# 3              0            0                  50            0
# 4              0            0                  73            0
# 5              0            0                  85            0
# 6              0            0                  59            0
# 7              0            0                  63            0
# 8              0            0                  83            0
# 9              1            0                  54            0

# %%
promotions.isna().mean()

# 4.d there are still missing values in previous_year_rating
# Out:
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    0.075244
# length_of_service       0.000000
# kpis_met >80%           0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64

# %%
promotions.previous_year_rating = promotions.previous_year_rating.fillna(promotions.previous_year_rating.median())
promotions.isna().sum().sum()

# we filled the cells that have missing values with the median value
# Out:
# 0

# %%
promotions.head()
# Out:
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    kpis_met >80%  awards_won?  avg_training_score  is_promoted
# 0              1            0                  49            0
# 1              0            0                  60            0
# 2              0            0                  50            0
# 3              0            0                  50            0
# 4              0            0                  73            0

# %%
promotions.is_promoted.value_counts(normalize=True).plot(kind='bar');
promotions.is_promoted.value_counts(normalize=True)

# 4.e distribution of the label
# Out:
# 0    0.91483
# 1    0.08517
# Name: is_promoted, dtype: float64

# %%
promotions.describe()
# Out:
#        no_of_trainings           age  previous_year_rating  length_of_service  \
# count     54808.000000  54808.000000          54808.000000       54808.000000
# mean          1.253011     34.803915              3.304481           5.865512
# std           0.609264      7.660169              1.214770           4.265094
# min           1.000000     20.000000              1.000000           1.000000
# 25%           1.000000     29.000000              3.000000           3.000000
# 50%           1.000000     33.000000              3.000000           5.000000
# 75%           1.000000     39.000000              4.000000           7.000000
# max          10.000000     60.000000              5.000000          37.000000
#
#        kpis_met >80%   awards_won?  avg_training_score   is_promoted
# count   54808.000000  54808.000000        54808.000000  54808.000000
# mean        0.351974      0.023172           63.386750      0.085170
# std         0.477590      0.150450           13.371559      0.279137
# min         0.000000      0.000000           39.000000      0.000000
# 25%         0.000000      0.000000           51.000000      0.000000
# 50%         0.000000      0.000000           60.000000      0.000000
# 75%         1.000000      0.000000           76.000000      0.000000
# max         1.000000      1.000000           99.000000      1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,8))
sns.heatmap(promotions.corr(), annot = True, cmap='coolwarm',linewidths=.1)
plt.show()

# 4.e correlation matrix

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(promotions, test_size=11000, random_state=0, shuffle=True)
label = 'is_promoted'
X_train, y_train = train.drop(label, axis=1), train[label]
X_test, y_test = test.drop(label, axis=1), test[label]

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape

# 4.a we have 43808 examples in the training set and 11000 in the test set
# Out:
# ((43808, 7), (43808,), (11000, 7), (11000,))

# %%
y_train.value_counts()

# 6.a.ii
# Out:
# 0    40067
# 1     3741
# Name: is_promoted, dtype: int64

# %%
import numpy as np
def get_benchmark_predictions(x, benchmark_value):
    # returns a numpy array on the same length as x with all values equal to benchmark_value
    return np.ones(len(x))*benchmark_value

benchmark_value = 0 # we set this benchmark value because of the train set majortiy values

y_train_pred = get_benchmark_predictions(X_train, benchmark_value)
y_test_pred = get_benchmark_predictions(X_test, benchmark_value)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

# 6.a.ii

# %%
from sklearn.metrics import mean_squared_error


def check_regressor(regressor, X_train, y_train, X_test, y_test):
    # Fit regression model
    regressor.fit(X_train, y_train)

    # Predict
    y_pred = regressor.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    y_pred_train = regressor.predict(X_train)
    mse_train = mean_squared_error(y_train, y_pred_train)
    
    model_name = regressor.__class__.__name__
    print('{0} mean squared error is {1:.4f} (mse train {2:.4f})'.format(model_name, mse, mse_train))
    return mse, mse_train, model_name

#6.a.i

# %%
models_errors = {}
models_errors_train = {}

# %%
class Benchmark:
    def fit(self, x, y):
        self.value = y.mean()
        return self
    
    def predict(self, x):
        return np.ones(len(x))*self.value
    
benchmark = Benchmark()
model_mse, model_mse_train, model_name = check_regressor(benchmark, X_train, y_train, X_test, y_test)
models_errors[model_name] = model_mse
models_errors_train[model_name] = model_mse_train

# 6.a.i
# Out:
# Benchmark mean squared error is 0.0772 (mse train 0.0781)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
import numpy as np

clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train, y_train)

y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

train_acc, test_acc

def plot_confusion_matrix(cm, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    classes = np.array(range(10))

    fig, ax = plt.subplots(figsize=(5, 5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title='Confusion matrix',
           ylabel='True label',
           xlabel='Predicted label')

    # Loop over data dimensions and create text annotations.
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], 'd'),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))


# 6.b.i
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     10073
#            1       0.41      0.16      0.23       927
#
#     accuracy                           0.91     11000
#    macro avg       0.67      0.57      0.59     11000
# weighted avg       0.88      0.91      0.89     11000

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=7)
clf.fit(X_train, y_train)

y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

train_acc, test_acc

def plot_confusion_matrix(cm, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    classes = np.array(range(10))

    fig, ax = plt.subplots(figsize=(5, 5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title='Confusion matrix',
           ylabel='True label',
           xlabel='Predicted label')

    # Loop over data dimensions and create text annotations.
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], 'd'),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 6.b.i
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     10073
#            1       0.72      0.13      0.22       927
#
#     accuracy                           0.92     11000
#    macro avg       0.82      0.56      0.59     11000
# weighted avg       0.91      0.92      0.90     11000

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=10)
clf.fit(X_train, y_train)

y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

train_acc, test_acc

def plot_confusion_matrix(cm, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    classes = np.array(range(10))

    fig, ax = plt.subplots(figsize=(5, 5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title='Confusion matrix',
           ylabel='True label',
           xlabel='Predicted label')

    # Loop over data dimensions and create text annotations.
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], 'd'),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 6.b.i
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     10073
#            1       0.80      0.11      0.20       927
#
#     accuracy                           0.92     11000
#    macro avg       0.86      0.55      0.58     11000
# weighted avg       0.91      0.92      0.90     11000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train_scaled, y_train)

y_train_pred = clf.predict(X_train_scaled)
y_test_pred = clf.predict(X_test_scaled)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

train_acc, test_acc

def plot_confusion_matrix(cm, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    classes = np.array(range(10))

    fig, ax = plt.subplots(figsize=(5, 5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title='Confusion matrix',
           ylabel='True label',
           xlabel='Predicted label')

    # Loop over data dimensions and create text annotations.
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], 'd'),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 6.b.ii
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     10073
#            1       0.42      0.21      0.28       927
#
#     accuracy                           0.91     11000
#    macro avg       0.68      0.59      0.62     11000
# weighted avg       0.89      0.91      0.90     11000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

clf = KNeighborsClassifier(n_neighbors=7)
clf.fit(X_train_scaled, y_train)

y_train_pred = clf.predict(X_train_scaled)
y_test_pred = clf.predict(X_test_scaled)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_pred)

train_acc, test_acc

def plot_confusion_matrix(cm, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    classes = np.array(range(10))

    fig, ax = plt.subplots(figsize=(5, 5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title='Confusion matrix',
           ylabel='True label',
           xlabel='Predicted label')

    # Loop over data dimensions and create text annotations.
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], 'd'),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 6.b.ii
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     10073
#            1       0.61      0.17      0.26       927
#
#     accuracy                           0.92     11000
#    macro avg       0.77      0.58      0.61     11000
# weighted avg       0.90      0.92      0.90     11000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

clf = KNeighborsClassifier(n_neighbors=10)
clf.fit(X_train_scaled, y_train)

y_train_pred = clf.predict(X_train_scaled)
y_test_pred = clf.predict(X_test_scaled)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

train_acc, test_acc

def plot_confusion_matrix(cm, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    classes = np.array(range(10))

    fig, ax = plt.subplots(figsize=(5, 5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title='Confusion matrix',
           ylabel='True label',
           xlabel='Predicted label')

    # Loop over data dimensions and create text annotations.
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], 'd'),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 6.b.ii
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     10073
#            1       0.78      0.13      0.23       927
#
#     accuracy                           0.92     11000
#    macro avg       0.86      0.57      0.59     11000
# weighted avg       0.91      0.92      0.90     11000

# %%
# %matplotlib inline
import pandas as pd
pd.options.display.max_columns = 30
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

train_acc = []
test_acc = []

decision_tree = DecisionTreeClassifier(max_depth=3, random_state=0)
decision_tree.fit(X_train, y_train)
train_acc.append(decision_tree.score(X_train, y_train))
test_acc.append(decision_tree.score(X_test, y_test))

y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

train_acc, test_acc

from sklearn.tree import export_graphviz
import matplotlib.pyplot as plt
from IPython.display import SVG
from graphviz import Source


def plot_tree(tree, features, labels):
    graph = Source(export_graphviz(tree, feature_names=features, class_names=labels, filled = True))
    display(SVG(graph.pipe(format='svg')))

plot_tree(decision_tree, features=X_train.columns, labels=['Not Promoted', 'Promoted'])

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 6.b.iii
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     10073
#            1       0.83      0.11      0.20       927
#
#     accuracy                           0.92     11000
#    macro avg       0.88      0.56      0.58     11000
# weighted avg       0.92      0.92      0.90     11000

# %%
# %matplotlib inline
import pandas as pd
pd.options.display.max_columns = 30
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

train_acc = []
test_acc = []

decision_tree = DecisionTreeClassifier(max_depth=4, random_state=0)
decision_tree.fit(X_train, y_train)
train_acc.append(decision_tree.score(X_train, y_train))
test_acc.append(decision_tree.score(X_test, y_test))

y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

train_acc, test_acc

from sklearn.tree import export_graphviz
import matplotlib.pyplot as plt
from IPython.display import SVG
from graphviz import Source


def plot_tree(tree, features, labels):
    graph = Source(export_graphviz(tree, feature_names=features, class_names=labels, filled = True))
    display(SVG(graph.pipe(format='svg')))

plot_tree(decision_tree, features=X_train.columns, labels=['Not Promoted', 'Promoted'])

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 6.b.iii
# 7
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     10073
#            1       0.78      0.17      0.27       927
#
#     accuracy                           0.93     11000
#    macro avg       0.86      0.58      0.62     11000
# weighted avg       0.92      0.93      0.90     11000

# %%
# %matplotlib inline
import pandas as pd
pd.options.display.max_columns = 30
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

train_acc = []
test_acc = []

decision_tree = DecisionTreeClassifier(max_depth=5, random_state=0)
decision_tree.fit(X_train, y_train)
train_acc.append(decision_tree.score(X_train, y_train))
test_acc.append(decision_tree.score(X_test, y_test))

y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

train_acc, test_acc

from sklearn.tree import export_graphviz
import matplotlib.pyplot as plt
from IPython.display import SVG
from graphviz import Source


def plot_tree(tree, features, labels):
    graph = Source(export_graphviz(tree, feature_names=features, class_names=labels, filled = True))
    display(SVG(graph.pipe(format='svg')))

plot_tree(decision_tree, features=X_train.columns, labels=['Not Promoted', 'Promoted'])

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 6.b.iii
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     10073
#            1       0.81      0.16      0.27       927
#
#     accuracy                           0.93     11000
#    macro avg       0.87      0.58      0.61     11000
# weighted avg       0.92      0.93      0.90     11000

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=100, random_state=0, max_depth=3)
random_forest.fit(X_train, y_train)

y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

feature_importances = random_forest.feature_importances_
features = X_train.columns
stats = pd.DataFrame({'feature':features, 'importance':feature_importances})
stats.head(10)

#6.b.iv
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     10073
#            1       0.91      0.11      0.20       927
#
#     accuracy                           0.92     11000
#    macro avg       0.92      0.56      0.58     11000
# weighted avg       0.92      0.92      0.90     11000
#                 feature  importance
# 0       no_of_trainings    0.002245
# 1                   age    0.007020
# 2  previous_year_rating    0.110499
# 3     length_of_service    0.004191
# 4         kpis_met >80%    0.249129
# 5           awards_won?    0.151825
# 6    avg_training_score    0.475091

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=100, random_state=0, max_depth=4)
random_forest.fit(X_train, y_train)

y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

feature_importances = random_forest.feature_importances_
features = X_train.columns
stats = pd.DataFrame({'feature':features, 'importance':feature_importances})
stats.head(10)

#6.b.iv
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     10073
#            1       0.91      0.12      0.21       927
#
#     accuracy                           0.92     11000
#    macro avg       0.92      0.56      0.58     11000
# weighted avg       0.92      0.92      0.90     11000
#                 feature  importance
# 0       no_of_trainings    0.002701
# 1                   age    0.008293
# 2  previous_year_rating    0.109430
# 3     length_of_service    0.006718
# 4         kpis_met >80%    0.231206
# 5           awards_won?    0.137382
# 6    avg_training_score    0.504270

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=100, random_state=0, max_depth=5)
random_forest.fit(X_train, y_train)

y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

feature_importances = random_forest.feature_importances_
features = X_train.columns
stats = pd.DataFrame({'feature':features, 'importance':feature_importances})
stats.head(10)

#6.b.iv
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     10073
#            1       0.91      0.13      0.23       927
#
#     accuracy                           0.93     11000
#    macro avg       0.92      0.57      0.60     11000
# weighted avg       0.92      0.93      0.90     11000
#                 feature  importance
# 0       no_of_trainings    0.003914
# 1                   age    0.012573
# 2  previous_year_rating    0.102643
# 3     length_of_service    0.013882
# 4         kpis_met >80%    0.227274
# 5           awards_won?    0.137446
# 6    avg_training_score    0.502268

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

test_precision = []

for k in range (1,7):
    random_forest = RandomForestClassifier(n_estimators=100, random_state=0, max_depth=k)
    random_forest.fit(X_train, y_train)
    y_train_pred = random_forest.predict(X_train)
    y_test_pred = random_forest.predict(X_test)
    precision = precision_score(y_test, y_test_pred)
    test_precision.append(precision)
    
# 8
# Out:
# C:\Users\aner\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(range(1, 7) ,test_precision, s=10, c='r', marker="o")
ax1.set_ylabel("Precision")
ax1.set_xlabel("k")

plt.legend(loc='upper left');
plt.show()

# 8
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.ensemble import AdaBoostClassifier

Ada_boost = AdaBoostClassifier(n_estimators=100, random_state=0)
Ada_boost.fit(X_train, y_train)

y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 6.b.v
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     10073
#            1       0.90      0.14      0.25       927
#
#     accuracy                           0.93     11000
#    macro avg       0.92      0.57      0.60     11000
# weighted avg       0.92      0.93      0.90     11000

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=1)
model_mse, model_mse_train, model_name = check_regressor(lasso, X_train, y_train, X_test, y_test)
models_errors[model_name] = model_mse
models_errors_train[model_name] = model_mse_train

lasso = Lasso(alpha=0.5)
model_mse, model_mse_train, model_name = check_regressor(lasso, X_train, y_train, X_test, y_test)
models_errors[model_name] = model_mse
models_errors_train[model_name] = model_mse_train

lasso = Lasso(alpha=0.2)
model_mse, model_mse_train, model_name = check_regressor(lasso, X_train, y_train, X_test, y_test)
models_errors[model_name] = model_mse
models_errors_train[model_name] = model_mse_train

# 6.b.vi
# Out:
# Lasso mean squared error is 0.0772 (mse train 0.0781)
# Lasso mean squared error is 0.0760 (mse train 0.0769)
# Lasso mean squared error is 0.0749 (mse train 0.0758)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
models = []
models.append(('KNN', KNeighborsClassifier(n_neighbors=10)))
models.append(('DecisionTree', DecisionTreeClassifier(max_depth=3, random_state=0)))
models.append(('RandomForest', RandomForestClassifier(n_estimators=100,max_depth=5)))
models.append(('AdaBoost', AdaBoostClassifier(n_estimators=100)))

# evaluate each model in turn
results = []
names = []
scoring = 'recall'
for name, model in models:
	kfold = KFold(n_splits=10)
	cv_results = cross_val_score(model, X_train,y_train, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# 8
# Out:
# KNN: 0.106625 (0.011116)
# DecisionTree: 0.108019 (0.008830)
# RandomForest: 0.124398 (0.010717)
# AdaBoost: 0.145616 (0.015129)

# %%
X= promotions.drop('is_promoted',axis=1)
y=promotions['is_promoted']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.1,random_state=42)

from sklearn.ensemble import AdaBoostClassifier

Ada_boost = AdaBoostClassifier(n_estimators=100, random_state=0)
Ada_boost.fit(X_train, y_train)

y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 9.a
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      5050
#            1       0.93      0.15      0.26       431
#
#     accuracy                           0.93      5481
#    macro avg       0.93      0.57      0.61      5481
# weighted avg       0.93      0.93      0.91      5481

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.3,random_state=42)

from sklearn.ensemble import AdaBoostClassifier

Ada_boost = AdaBoostClassifier(n_estimators=100, random_state=0)
Ada_boost.fit(X_train, y_train)

y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))
# 9.a
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     15110
#            1       0.93      0.13      0.23      1333
#
#     accuracy                           0.93     16443
#    macro avg       0.93      0.57      0.60     16443
# weighted avg       0.93      0.93      0.90     16443

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.5,random_state=42)

from sklearn.ensemble import AdaBoostClassifier

Ada_boost = AdaBoostClassifier(n_estimators=100, random_state=0)
Ada_boost.fit(X_train, y_train)

y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))
# 9.a
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     25152
#            1       0.94      0.13      0.23      2252
#
#     accuracy                           0.93     27404
#    macro avg       0.93      0.56      0.60     27404
# weighted avg       0.93      0.93      0.90     27404

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.7,random_state=42)

from sklearn.ensemble import AdaBoostClassifier

Ada_boost = AdaBoostClassifier(n_estimators=100, random_state=0)
Ada_boost.fit(X_train, y_train)

y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 9.a
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     35152
#            1       0.94      0.13      0.23      3214
#
#     accuracy                           0.93     38366
#    macro avg       0.93      0.57      0.60     38366
# weighted avg       0.93      0.93      0.90     38366

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=1,random_state=42)

from sklearn.ensemble import AdaBoostClassifier

Ada_boost = AdaBoostClassifier(n_estimators=100, random_state=0)
Ada_boost.fit(X_train, y_train)

y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)
plot_confusion_matrix(cm)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))

# 9.a
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1
